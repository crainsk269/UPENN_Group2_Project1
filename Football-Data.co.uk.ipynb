# %%
import pandas as pd
import os

# %%
directory = 'Football_Games_Data'
csv_files = []

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    csv_files.append(f)
# full_df = pd.concat([pd.read_csv(file) for file in csv_files])
# full_df

l = []
for file in csv_files:
    f = pd.read_csv(file)
    f.loc[:,'File Name'] = file
    l.append(f)
games_df = pd.concat(l)
games_df
# Out:
#     Div        Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0    18/08/12         Arsenal   Sunderland   0.0   0.0   D   0.0   0.0
# 1    E0    18/08/12          Fulham      Norwich   5.0   0.0   H   2.0   0.0
# 2    E0    18/08/12       Newcastle    Tottenham   2.0   1.0   H   0.0   0.0
# 3    E0    18/08/12             QPR      Swansea   0.0   5.0   A   0.0   1.0
# 4    E0    18/08/12         Reading        Stoke   1.0   1.0   D   0.0   1.0
# ..   ..         ...             ...          ...   ...   ...  ..   ...   ...
# 375  E0  22/05/2022  Crystal Palace   Man United   1.0   0.0   H   1.0   0.0
# 376  E0  22/05/2022       Leicester  Southampton   4.0   1.0   H   0.0   0.0
# 377  E0  22/05/2022       Liverpool       Wolves   3.0   1.0   H   1.0   1.0
# 378  E0  22/05/2022        Man City  Aston Villa   3.0   2.0   H   0.0   1.0
# 379  E0  22/05/2022         Norwich    Tottenham   0.0   5.0   A   0.0   2.0
#
# ...

# %%
new_games_df = games_df.loc[:, ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HS', 'AS', 'HST', 'AST',\
                                'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'File Name']]
new_games_df
# Out:
#            Date        HomeTeam     AwayTeam  FTHG  FTAG    HS    AS   HST  \
# 0      18/08/12         Arsenal   Sunderland   0.0   0.0  14.0   3.0   4.0
# 1      18/08/12          Fulham      Norwich   5.0   0.0  11.0   4.0   9.0
# 2      18/08/12       Newcastle    Tottenham   2.0   1.0   6.0  12.0   4.0
# 3      18/08/12             QPR      Swansea   0.0   5.0  20.0  12.0  11.0
# 4      18/08/12         Reading        Stoke   1.0   1.0   9.0   6.0   3.0
# ..          ...             ...          ...   ...   ...   ...   ...   ...
# 375  22/05/2022  Crystal Palace   Man United   1.0   0.0   6.0  10.0   3.0
# 376  22/05/2022       Leicester  Southampton   4.0   1.0  12.0   7.0   6.0
# 377  22/05/2022       Liverpool       Wolves   3.0   1.0  29.0   7.0   8.0
# 378  22/05/2022        Man City  Aston Villa   3.0   2.0  24.0   4.0   5.0
# 379  22/05/2022         Norwich    Tottenham   0.0   5.0   9.0  19.0   0.0
#
#       AST    HC   AC    HF    AF   HY   AY   HR   AR  \
# ...
